# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
groq_api_key = os.getenv('GROQ_API_KEY')

if groq_api_key:
    print(f"GROQ API Key exists and begins {groq_api_key[:8]}")
else:
    print("GROQ API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# GROQ API Key not set - please head to the troubleshooting guide in the setup folder

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from groq import Groq

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

groq = Groq()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = groq.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Here's one: Did you know that there is a species of jellyfish that is immortal? The Turritopsis dohrnii, also known as the "immortal jellyfish," can transform its body into a younger state through a process called transdifferentiation. This means that it can essentially revert back to its polyp stage and grow back into an adult again, making it theoretically immortal! Isn't that cool?

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = groq.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=messages
)
question = response.choices[0].message.content
print(question)
# Out:
# A snail is at the bottom of a 20-foot well. Each day, it climbs up 3 feet, but at night, it slips back 2 feet. On what day will the snail reach the top of the well, and how many feet will it have climbed in total, assuming it climbs during the day and slips at night, and it reaches the top at the exact end of a day, just before slipping back?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'A snail is at the bottom of a 20-foot well. Each day, it climbs up 3 feet, but at night, it slips back 2 feet. On what day will the snail reach the top of the well, and how many feet will it have climbed in total, assuming it climbs during the day and slips at night, and it reaches the top at the exact end of a day, just before slipping back?'}]

# %%
# Ask the model to answer the hard question

response = groq.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# To find out on which day the snail will reach the top of the well, we first observe the daily progress of the snail. Each day, it effectively climbs 3 feet but then slips back 2 feet at night, resulting in a net gain of 1 foot per day.
#
# However, on the final day of its climb to the top, the snail won't slip back because it reaches the top just before slipping back would occur.
#
# The well is 20 feet deep. If the snail climbs 3 feet each day and slips back 2 feet each night, it makes a net progress of 1 foot per day.
#
# On the 17th day, it would have climbed 17 feet (since 16 days of net progress of 1 foot each, plus the 3 feet it climbs on the 17th day). At this point, it's 3 feet short of the top.
#
# On the 18th day, when it climbs its 3 feet, it will reach the top of the 20-foot well, just before it would slip back. Thus, it takes 18 days for the snail to reach the top of the well.
#
# To calculate the total feet it has climbed, we consider the following:
#
# - For the first 17 days, it climbs 3 feet each day and slips back 2 feet each night, so it effectively climbs 1 foot per day but actually moves 3 feet up and 2 feet back each day. This means it climbs 3 feet * 17 days = 51 feet up and slips back 2 feet * 17 days = 34 feet.
# - On the 18th day, it climbs the final 3 feet to reach the top.
#
# So, the total feet climbed is 51 feet (from the first 17 days) + 3 feet (on the 18th day) = 54 feet.
#
# The snail will reach the top of the well on the 18th day, and it will have climbed a total of 54 feet.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To find out on which day the snail will reach the top of the well, we first observe the daily progress of the snail. Each day, it effectively climbs 3 feet but then slips back 2 feet at night, resulting in a net gain of 1 foot per day.
#
# However, on the final day of its climb to the top, the snail won't slip back because it reaches the top just before slipping back would occur.
#
# The well is 20 feet deep. If the snail climbs 3 feet each day and slips back 2 feet each night, it makes a net progress of 1 foot per day.
#
# On the 17th day, it would have climbed 17 feet (since 16 days of net progress of 1 foot each, plus the 3 feet it climbs on the 17th day). At this point, it's 3 feet short of the top.
#
# On the 18th day, when it climbs its 3 feet, it will reach the top of the 20-foot well, just before it would slip back. Thus, it takes 18 days for the snail to reach the top of the well.
#
# To calculate the total feet it has climbed, we consider the following:
#
# - For the first 17 days, it climbs 3 feet each day and slips back 2 feet each night, so it effectively climbs 1 foot per day but actually moves 3 feet up and 2 feet back each day. This means it climbs 3 feet * 17 days = 51 feet up and slips back 2 feet * 17 days = 34 feet.
# - On the 18th day, it climbs the final 3 feet to reach the top.
#
# So, the total feet climbed is 51 feet (from the first 17 days) + 3 feet (on the 18th day) = 54 feet.
#
# The snail will reach the top of the well on the 18th day, and it will have climbed a total of 54 feet.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# A snail is at the bottom of a 20-foot well. Each day, it climbs up 3 feet, but at night, it slips back 2 feet. On what day will the snail reach the top of the well, and how many feet will it have climbed in total, assuming it climbs during the day and slips at night, and it reaches the top at the exact end of a day, just before slipping back?
#
# And here is a possible answer that might be correct or incorrect:
# To find out on which day the snail will reach the top of the well, we first observe the daily progress of the snail. Each day, it effectively climbs 3 feet but then slips back 2 feet at night, resulting in a net gain of 1 foot per day.
#
# However, on the final day of its climb to the top, the snail won't slip back because it reaches the top just before slipping back would occur.
#
# The well is 20 feet deep. If the snail climbs 3 feet each day and slips back 2 feet each night, it makes a net progress of 1 foot per day.
#
# On the 17th day, it would have climbed 17 feet (since 16 days of net progress of 1 foot each, plus the 3 feet it climbs on the 17th day). At this point, it's 3 feet short of the top.
#
# On the 18th day, when it climbs its 3 feet, it will reach the top of the 20-foot well, just before it would slip back. Thus, it takes 18 days for the snail to reach the top of the well.
#
# To calculate the total feet it has climbed, we consider the following:
#
# - For the first 17 days, it climbs 3 feet each day and slips back 2 feet each night, so it effectively climbs 1 foot per day but actually moves 3 feet up and 2 feet back each day. This means it climbs 3 feet * 17 days = 51 feet up and slips back 2 feet * 17 days = 34 feet.
# - On the 18th day, it climbs the final 3 feet to reach the top.
#
# So, the total feet climbed is 51 feet (from the first 17 days) + 3 feet (on the 18th day) = 54 feet.
#
# The snail will reach the top of the well on the 18th day, and it will have climbed a total of 54 feet.
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = groq.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=messages
)
print(response.choices[0].message.content)
# Out:
# The answer is correct.
#
# Here's the breakdown:
#
# 1. **Day calculation**: The snail makes a net progress of 1 foot per day. Since the well is 20 feet deep, on the 17th day, the snail would have made a net progress of 17 feet (17 days * 1 foot per day), and with the additional 3 feet it climbs on the 17th day, it would be at 20 feet. However, because it slips back 2 feet each night, it actually falls short by 2 feet from the top at the end of the 17th day (before slipping), not 3 feet as mentioned in the possible answer. This minor discrepancy does not affect the final day calculation because the snail reaches the top on the 18th day as explained.
#
# 2. **Total feet climbed**: The calculation for the total feet climbed is correct.
#    - For the first 17 days, the snail climbs 3 feet each day and slips back 2 feet each night. So, it climbs 3 feet * 17 days = 51 feet and slips back 2 feet * 17 days = 34 feet.
#    - On the 18th day, it climbs the final 3 feet to reach the top.
#    - Therefore, the total feet climbed is indeed 51 feet (from the first 17 days) + 3 feet (on the 18th day) = 54 feet.
#
# The explanation provided accurately describes the snail's progress and correctly calculates the day it reaches the top of the well and the total distance climbed. Therefore, the conclusion that the snail will reach the top of the well on the 18th day and will have climbed a total of 54 feet is correct.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:
question = "Please propose a business idea that is both innovative and feasible. Respond only with the business idea."
messages = [{"role": "user", "content": question}]

# Then make the first call:

response =groq.chat.completions.create(model="llama-3.3-70b-versatile", messages=messages)

# Then read the business idea:

business_area = response.choices[0].message.content
print(business_area)
# And repeat! In the next message, include the business area within the message
# Out:
# EcoCycle: A Smart Recycling Platform that utilizes AI-powered sorting machines and a mobile app to streamline the recycling process, allowing users to deposit recyclables at conveniently located kiosks, track their environmental impact, and receive rewards in the form of discounts, coupons, or cashback at local sustainable businesses.

# %%
from IPython.display import Markdown, display

display(Markdown(business_area))
# Out:
# EcoCycle: A Smart Recycling Platform that utilizes AI-powered sorting machines and a mobile app to streamline the recycling process, allowing users to deposit recyclables at conveniently located kiosks, track their environmental impact, and receive rewards in the form of discounts, coupons, or cashback at local sustainable businesses.

# %%
question = f"Propose a solution to the pain-point in the Real Estate Brokerage Industry. Business idea: {business_area}"

messages = [{"role": "user", "content": question}]

response =groq.chat.completions.create(model="llama-3.3-70b-versatile", messages=messages)


solution = response.choices[0].message.content


from IPython.display import Markdown, display

display(Markdown(solution))
# Out:
# It appears that the provided business idea, EcoCycle, is actually a solution for a pain-point in the Waste Management Industry, not the Real Estate Brokerage Industry. However, I can propose a solution to a pain-point in the Real Estate Brokerage Industry, and then provide an analysis of the EcoCycle business idea.
#
# **Pain-point in the Real Estate Brokerage Industry:**
# One significant pain-point in the Real Estate Brokerage Industry is the lack of transparency and efficiency in the home buying and selling process. Buyers and sellers often experience frustration with the slow pace of transactions, lack of communication, and limited access to relevant information.
#
# **Solution:**
# Proposed solution: "Elevate" - A Digital Real Estate Brokerage Platform that utilizes AI-powered tools, blockchain technology, and a user-friendly interface to streamline the home buying and selling process.
#
# Key Features:
#
# 1. **Smart Property Matching**: AI-powered matching algorithm that connects buyers with relevant properties based on their preferences, budget, and lifestyle.
# 2. **Transparent Transaction Management**: Blockchain-based platform that provides a secure, transparent, and tamper-proof record of all transactions, ensuring accountability and trust among parties involved.
# 3. **Real-time Market Insights**: Data analytics and market trends provided to buyers and sellers, enabling informed decisions and strategic negotiations.
# 4. **Streamlined Communication**: Integrated messaging system and automated updates keep all parties informed throughout the transaction process.
# 5. **Digital Document Management**: Secure, electronic storage and signing of documents, reducing paperwork and expediting the closing process.
# 6. **Personalized Agent Support**: Human agents assisted by AI-powered tools provide guidance, support, and expertise to buyers and sellers.
#
# **Benefits:**
#
# * Increased efficiency and transparency in transactions
# * Improved communication and collaboration among parties involved
# * Enhanced user experience through personalized support and real-time market insights
# * Reduced paperwork and increased security through digital document management
# * Increased agent productivity and effectiveness
#
# Now, regarding the EcoCycle business idea:
#
# **EcoCycle: A Smart Recycling Platform**
#
# The EcoCycle platform addresses a significant pain-point in the Waste Management Industry by providing a convenient, efficient, and rewarding recycling experience for users. The use of AI-powered sorting machines and a mobile app to track environmental impact and reward users is innovative and engaging.
#
# **Key Strengths:**
#
# 1. **Convenience**: Conveniently located kiosks make it easy for users to deposit recyclables.
# 2. **Education and Awareness**: The platform raises awareness about the importance of recycling and provides users with a sense of accomplishment and contribution to environmental sustainability.
# 3. **Rewards and Incentives**: Rewards in the form of discounts, coupons, or cashback at local sustainable businesses encourage users to participate and continue recycling.
# 4. **Data-Driven Insights**: The platform can provide valuable data on recycling patterns, trends, and areas for improvement, helping to optimize waste management strategies.
#
# **Potential Challenges:**
#
# 1. **Infrastructure and Logistics**: Establishing a network of kiosks and maintaining the AI-powered sorting machines may require significant investment and resources.
# 2. **User Adoption and Engagement**: Encouraging users to adopt the platform and maintain consistent participation may be a challenge, requiring effective marketing and education campaigns.
# 3. **Partnerships and Collaborations**: Building partnerships with local sustainable businesses and waste management organizations may be necessary to ensure the success and scalability of the platform.
#
# Overall, both Elevate (the proposed solution for the Real Estate Brokerage Industry) and EcoCycle (the provided business idea for the Waste Management Industry) have the potential to address significant pain-points and create value for users. However, each requires careful consideration of the challenges and opportunities involved in their respective markets.
