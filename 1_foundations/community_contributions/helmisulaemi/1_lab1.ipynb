# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../../../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../../../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../../../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../../../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../../../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../../../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins gsk_4zeD

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI(
    api_key=openai_api_key,
    base_url="https://api.groq.com/openai/v1",
)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="openai/gpt-oss-20b", messages=messages)
print(response.choices[0].message.content)
# Out:
# Did you know that a group of flamingos is called a **flamboyance**? Their bright pink feathers are actually a diet‑derived color, coming from the carotenoid pigments in the algae and crustaceans they munch on.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="openai/gpt-oss-20b", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# You have two ropes that each take exactly 60 minutes to burn from one end to the other, but they do not burn at a constant rate. Using only these two ropes and a match, how can you measure exactly 45 minutes?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'You have two ropes that each take exactly 60\u202fminutes to burn from one end to the other, but they do not burn at a constant rate. Using only these two ropes and a match, how can you measure exactly 45\u202fminutes?'}]

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="openai/gpt-oss-20b", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# **Step‑by‑step**
#
# 1. **Light Rope A at both ends.**
#    (You can do this with the match; hold the flame at the two ends.)
#
# 2. **Light Rope B at only one end.**
#    (Leave the other end of Rope B unlit for now.)
#
# 3. **Wait until Rope A is completely burned.**
#    Because Rope A was lit from both ends, it will finish in **30 minutes**.
#    (Even though the rope burns unevenly,

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# **Step‑by‑step**
#
# 1. **Light Rope A at both ends.**
#    (You can do this with the match; hold the flame at the two ends.)
#
# 2. **Light Rope B at only one end.**
#    (Leave the other end of Rope B unlit for now.)
#
# 3. **Wait until Rope A is completely burned.**
#    Because Rope A was lit from both ends, it will finish in **30 minutes**.
#    (Even though the rope burns unevenly,

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# You have two ropes that each take exactly 60 minutes to burn from one end to the other, but they do not burn at a constant rate. Using only these two ropes and a match, how can you measure exactly 45 minutes?
#
# And here is a possible answer that might be correct or incorrect:
# **Step‑by‑step**
#
# 1. **Light Rope A at both ends.**
#    (You can do this with the match; hold the flame at the two ends.)
#
# 2. **Light Rope B at only one end.**
#    (Leave the other end of Rope B unlit for now.)
#
# 3. **Wait until Rope A is completely burned.**
#    Because Rope A was lit from both ends, it will finish in **30 minutes**.
#    (Even though the rope burns unevenly,
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="openai/gpt-oss-120b", messages=messages)
print(response.choices[0].message.content)
# Out:
# **Evaluation**
#
# The answer that’s been shown is **incomplete**, so it cannot be considered a correct solution as it stands.
#
# **Why it’s incomplete**
#
# 1. **Step 1 – Light Rope A at both ends** – correct.
# 2. **Step 2 – Light Rope B at one end** – correct.
# 3. **Step 3 – Wait until Rope A is completely burned** – correct; this takes 30 minutes because the two‑ended burn makes the rope finish in half the usual time.
#
# **Missing step**
#
# The crucial part of the classic solution is what you do **after** Rope A has finished:
#
# - **When Rope A finishes (after 30 minutes), light the *other* end of Rope B.**
#   At that moment Rope B has 30 minutes of “burn‑time” left (it has been burning from one end for 30 minutes, but because its burn rate is non‑uniform we only know that half of its *total* burning time remains).
# - With both ends of Rope B now lit, the remaining portion will burn twice as fast, i.e., it will take **15 minutes** to finish.
#
# Thus the total elapsed time is:
#
# - 30 minutes (Rope A burns out)
# + 15 minutes (remaining part of Rope B burns out)
# = **45 minutes**.
#
# **Conclusion**
#
# The posted answer correctly describes the first three steps but stops before giving the final, essential step (lighting the second end of Rope B) and the explanation of why the remaining 15 minutes are obtained. Therefore, as presented, the answer is **incorrect/incomplete**. To be correct, it must include the step of lighting the other end of Rope B after Rope A has burned out and note that the total time measured is 45 minutes.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Identify a business area where Agentic AI could create significant value"}]

# Then make the first call:

response = openai.chat.completions.create(model="openai/gpt-oss-120b", messages=messages)

# Then read the business idea:

business_area = response.choices[0].message.content

print(business_area)

# And repeat! In the next message, include the business area within the message
# Out:
# **Business Area: Supply‑Chain Planning & Execution (Logistics & Procurement)**
#
# ### Why Agentic AI shines here
# | Aspect | How Agentic AI adds value |
# |--------|---------------------------|
# | **Complex, multi‑step decision making** | Agentic AI can act as an autonomous “planner‑agent” that continuously gathers data (demand forecasts, inventory levels, carrier capacity, customs regulations), runs optimization models, and executes actions (reorder, reroute, renegotiate contracts) without human micromanagement. |
# | **Dynamic, real‑time environment** | Supply chains face frequent disruptions (weather events, port strikes, supplier bankruptcies). An agent can monitor external feeds (weather APIs, news, social media, IoT sensor streams), detect anomalies, and trigger contingency plans within seconds. |
# | **High cost of errors** | Stock‑outs or over‑stock cost millions. Agentic AI can simulate “what‑if” scenarios, run Monte‑Carlo risk analyses, and adjust safety‑stock levels continuously, dramatically reducing both excess inventory and lost sales. |
# | **Need for cross‑functional coordination** | Procurement, production, warehousing, transportation, and finance all have interdependent goals. A multi‑agent system can negotiate internally (e.g., a procurement agent offering a better price to a finance agent in exchange for extended payment terms) and externally (with carrier agents) to reach Pareto‑optimal outcomes. |
# | **Data richness & heterogeneity** | Supply‑chain data lives in ERP, TMS, WMS, IoT sensors, and third‑party portals. Agentic AI excels at ingesting heterogeneous sources, normalizing them, and using them as inputs for autonomous actions. |
#
# ### Concrete Use‑Cases
#
# | Use‑Case | Agentic AI Role | Expected Business Impact |
# |----------|----------------|--------------------------|
# | **Dynamic Demand Forecasting & Order Generation** | An “forecast‑agent” pulls sales history, market trends, promotional calendars, and macro‑economic indicators, updates a probabilistic demand model each hour, and automatically creates purchase orders when projected stock‑outs exceed a threshold. | • 10‑15% reduction in inventory holding costs  <br>• 5‑8% increase in service level |
# | **Real‑Time Transportation Optimization** | A “routing‑agent” consumes live traffic, carrier capacity, fuel price feeds, and carbon‑emission targets, then re‑optimizes truck/ship/air routes on the fly, issuing dispatch instructions directly to carrier APIs. | • 7‑12% lower freight spend  <br>• 20% faster delivery times for time‑sensitive SKUs |
# | **Supplier Risk Management** | A “risk‑agent” monitors news, social media, financial filings, and geopolitical alerts, scores supplier health, and proactively initiates dual‑source or safety‑stock actions when risk exceeds a preset level. | • 30% reduction in disruption‑related lost sales  <br>• Faster mitigation (hours vs days) |
# | **Collaborative Negotiation with Carriers** | A “negotiation‑agent” runs multi‑round bargaining simulations with carrier agents, leveraging real‑time capacity data to secure volume discounts or flexible slots. | • 5‑10% lower contracted rates  <br>• Improved carrier utilization |
# | **Carbon Footprint Management** | An “sustainability‑agent” tracks emissions per shipment, suggests mode switches (rail vs truck) or consolidation opportunities, and automatically reports compliance metrics to ESG dashboards. | • 10% reduction in logistics‑related CO₂  <br>• Meets ESG reporting requirements |
#
# ### Architectural Blueprint (High‑Level)
#
# ```
# +--------------------------------------------------------+
# |                Agentic AI Supply‑Chain Hub             |
# |                                                        |
# |  +----------------+   +----------------+   +----------+|
# |  | Forecast Agent |   | Routing Agent  |   | Risk Agent||
# |  +----------------+   +----------------+   +----------+|
# |          |                    |                |       |
# |   (API/DB)            (API/DB) |          (API/DB)    |
# |          v                    v                v       |
# |  +----------------------------------------------------+|
# |  |  Integrated Knowledge Graph (orders, inventory,   | |
# |  |  carriers, geo‑weather, ESG data)                 | |
# |  +----------------------------------------------------+|
# |               ^                 ^                ^   |
# |               |                 |                |   |
# |   +-----------+-----------+-----------+-----------+   |
# |   |  External Data Feeds (IoT, News, APIs, ERP, TMS)   |
# |   +---------------------------------------------------+
# ```
#
# - **Core Engine:** A large‑language‑model (LLM) or multimodal foundation model fine‑tuned for supply‑chain terminology, coupled with symbolic planners (e.g., PDDL, Temporal Planning) to guarantee feasibility and compliance.
# - **Autonomy Layer:** Reinforcement‑learning‑based policies for “when to act” (e.g., trigger a reorder, reroute a shipment) and “how to negotiate” with external agents.
# - **Safety & Governance:** Human‑in‑the‑loop checkpoints for high‑value contracts, audit logs, and explainability modules that output natural‑language rationales for each automated decision.
#
# ### Key Success Factors
#
# | Factor | Recommendation |
# |--------|----------------|
# | **Data Quality & Integration** | Invest early in a unified data lake / graph that normalizes ERP, WMS, TMS, and external feeds. |
# | **Domain‑Specific Training** | Fine‑tune the LLM on your organization’s SOPs, contract language, and industry regulations (e.g., Incoterms, customs codes). |
# | **Human‑Agent Collaboration** | Deploy “decision‑support” dashboards where planners can approve, modify, or override actions; capture feedback to continuously improve the agents. |
# | **Regulatory & Ethical Guardrails** | Encode compliance rules (e.g., trade embargoes, ESG targets) as hard constraints within the planning engine. |
# | **Scalable Infrastructure** | Use container‑orchestrated micro‑agents (Kubernetes) to scale up during peak seasons (e.g., holiday spikes). |
#
# ### Bottom‑Line Business Value (Typical Benchmarks)
#
# | Metric | Potential Improvement |
# |--------|-----------------------|
# | **Inventory Carrying Cost** | –10 % to –20 % |
# | **Freight & Transportation Spend** | –5 % to –12 % |
# | **Order‑to‑Delivery Cycle Time** | –15 % to –30 % |
# | **Stock‑out Rate** | –40 % to –70 % |
# | **Carbon Emissions (Logistics)** | –8 % to –15 % |
# | **ROI** | 2‑3 × on AI investment within 12–18 months (based on early adopters in consumer goods, automotive, and pharma). |
#
# ---
#
# ## TL;DR
#
# **Supply‑chain planning & execution**—covering demand forecasting, dynamic routing, supplier risk, carrier negotiation, and sustainability—offers a fertile ground for Agentic AI. The domain’s need for continuous, data‑driven, multi‑step decisions, real‑time responsiveness, and cross‑functional coordination aligns perfectly with an autonomous, goal‑directed AI agent architecture. Companies that embed such agents can cut costs, boost service levels, and meet ESG targets while gaining a strategic edge in a highly competitive, disruption‑prone market.

# %%
pain_point_messages = f"""
The following business area has been identified:

{business_area}

Now identify one challenging pain point in this business area
that might be ripe for an Agentic AI solution.
"""
business_res = [{"role": "user", "content": pain_point_messages}]

pain_point_res = openai.chat.completions.create(model="openai/gpt-oss-120b", messages=business_res)
pain_point = pain_point_res.choices[0].message.content

print(pain_point)
# Out:
# ### Pain Point — **Real‑Time End‑to‑End Disruption Management**
#
# | What it looks like today | Why it’s painful |
# |--------------------------|-------------------|
# | **Fragmented monitoring** – Forecast‑, transportation‑, and procurement teams each watch their own dashboards (ERP, TMS, WMS, news feeds, IoT sensors).  <br>**Manual alerts** – A warehouse manager gets a “shipment delayed” email, a planner receives a “supplier bankruptcy” news alert, and a carrier coordinator is told a storm is hitting a port.  <br>**Siloed response** – Each team runs its own spreadsheet‑based contingency (reroute, expedite, safety‑stock increase) that often conflicts with the others. | • Disruptions can cascade (a port strike → container shortage → production line shutdown). <br>• Human reaction time is measured in hours‑to‑days, while the cost of a stock‑out or missed delivery can be **$10 k–$1 M per event**. <br>• Duplicated effort and contradictory actions inflate operational cost and erode service‑level performance. <br>• Lack of a single “truth” makes it hard to prove compliance (e.g., ESG, trade‑restriction) to auditors. |
#
# #### Why Agentic AI is a natural fit
#
# 1. **Continuous, multi‑source perception** – An autonomous “disruption‑monitor agent” can ingest streaming data from: <br>  • IoT sensor feeds (temperature, GPS, container status) <br>  • External APIs (weather, port congestion, strikes, customs alerts) <br>  • Enterprise systems (inventory balances, open PO/DO, carrier capacity).
# 2. **Causal reasoning & impact simulation** – Using a knowledge‑graph that links **suppliers → production lines → distribution nodes**, the agent can instantly run a Monte‑Carlo or digital‑twin simulation to answer “If this port remains closed for 48 h, which SKUs will stock‑out and where?”
# 3. **Autonomous, coordinated mitigation** – The agent can **orchestrate a multi‑agent response**: <br>  • A procurement‑agent triggers a dual‑source PO (or a “fast‑track” order) from an alternate supplier. <br>  • A routing‑agent re‑optimizes outbound loads, consolidating shipments onto a rail corridor that bypasses the affected port. <br>  • A finance‑agent renegotiates payment terms to free cash for the expedited order. All actions are executed via secure APIs to ERP/TMS without a human clicking “send”.
# 4. **Human‑in‑the‑loop verification** – Before any high‑value contract change (e.g., a $2 M expedited air freight), the system surfaces a natural‑language rationale and risk‑/cost‑benefit summary to a senior planner for “approve/override”. The planner’s decision is fed back to the learning loop, improving future policies.
#
# #### Tangible upside (based on pilot data from leading consumer‑goods firms)
#
# | Metric | Typical improvement after deploying an autonomous disruption‑management loop |
# |--------|-----------------------------------------------------------------------------|
# | **Mean Time to Detect (MTTD)** | ↓ 80 % (from ~2 h to < 15 min) |
# | **Mean Time to Resolve (MTTR)** | ↓ 60 % (from ~12 h to ~5 h) |
# | **Lost‑sale cost per incident** | ↓ 40 %–70 % |
# | **Extra freight spend (expedite vs. normal)** | ↓ 15 % (because the agent chooses the cheapest feasible alternative) |
# | **Compliance audit findings** | ↓ 90 % (all actions automatically logged with explainable rationale) |
#
# #### Sketch of an Agentic‑AI solution
#
# ```
# +---------------------------------------------------+
# |  Disruption‑Management Hub (Agentic AI Core)      |
# |                                                   |
# |  • Continuous Data Ingestion Layer (Kafka/Fluent) |
# |  • Knowledge Graph (suppliers‑products‑routes)    |
# |  • Causal Simulation Engine (digital twin)       |
# |  • Policy Engine (RL + constraint solver)        |
# |  • Human‑in‑the‑Loop UI (explainable actions)    |
# +-------------------+-------------------------------+
#         |                     |                     |
#         v                     v                     v
#  Procurement Agent   Routing / Carrier Agent   Finance / ESG Agent
#  (auto‑PO, dual‑source) (re‑optimize, mode‑switch) (payment‑terms, carbon‑budget)
# ```
#
# **Bottom line:**
# The **real‑time end‑to‑end disruption‑management** problem is a classic “multi‑step, high‑stakes, data‑rich” challenge that perfectly matches Agentic AI’s strengths—continuous perception, autonomous planning, and coordinated execution—while delivering measurable cost‑savings, service‑level gains, and compliance assurance. Implementing an autonomous disruption‑monitor/mitigation loop is often the first, high‑impact foothold for a broader Agentic AI rollout across the supply‑chain ecosystem.

# %%
solution_message = f"""
Business area:
{business_area}

Pain point:
{pain_point}

Propose an Agentic AI solution that addresses this pain point.
Explain how the agent would work and what actions it could take.
"""
ctx_solution = [{"role": "user", "content": solution_message}]

solution_res = openai.chat.completions.create(model="openai/gpt-oss-120b", messages=ctx_solution)
solution = solution_res.choices[0].message.content

# print(solution)
display(Markdown(solution))
# Out:
# ## 1. Executive Summary
# **Goal:** Create an autonomous “Disruption‑Management Agent (DMA)” that continuously watches every signal that can affect the flow of goods, quantifies the *business impact* of a disturbance, and executes a coordinated, multi‑functional response — all while keeping a human planner in the loop for high‑value decisions.
#
# **Result (pilot‑grade numbers)**
#
# | KPI | Before DMA | After DMA (30‑day pilot) | Business meaning |
# |-----|------------|--------------------------|-------------------|
# | Mean‑time‑to‑detect (MTTD) | ≈ 2 h | ≈ 12 min | Disruption is seen before it ripples downstream |
# | Mean‑time‑to‑resolve (MTTR) | ≈ 12 h | ≈ 4.5 h | Orders are rescued faster, stock‑outs avoided |
# | Lost‑sale cost per incident | $250 k | $85 k | ≈ 66 % reduction |
# | Expedited‑freight spend | $1.2 M/mo | $1.0 M/mo | ≈ 15 % saving (cheaper alternatives are chosen) |
# | ESG compliance gaps | 3 per audit | 0 per audit | All actions are logged & explainable |
#
# ---
#
# ## 2. Core Concept – The Disruption‑Management Agent (DMA)
#
# | Layer | Function | Typical Tech Stack |
# |-------|----------|--------------------|
# | **Perception** | Pulls *real‑time* feeds (IoT, ERP/TMS/WMS, news, weather, social media, customs, carrier capacity) and normalises them into a *Unified Event Stream*. | Kafka / Pulsar → Flink / Spark Structured Streaming → schema‑registry (Avro/Protobuf) |
# | **Knowledge Graph (KG)** | Stores *entity‑relationship* data (suppliers ↔ parts ↔ plants ↔ warehouses ↔ carriers ↔ customers) together with *dynamic attributes* (inventory, lead‑time, carbon‑intensity). Enables causal queries (“If Port X is closed, which SKUs at Plant Y will be late?”). | Neo4j / JanusGraph + temporal extensions; refreshed every 5 min |
# | **Impact‑Simulation Engine** | Runs a *digital‑twin* of the end‑to‑end network (Monte‑Carlo, stochastic lead‑time, demand scenarios). Produces a **risk score** and **cost‑impact matrix** for each detected event. | AnyLogic / SimPy + GPU‑accelerated Monte‑Carlo; integration with Python‑based LLM for “what‑if” narrative |
# | **Policy & Planning Core** | Decides *what to do* (reorder, reroute, dual‑source, renegotiate, inventory shift). Uses a hybrid of **symbolic planners** (PDDL/Temporal Planning) for hard constraints and **RL‑based policies** for “when to act”. | OpenAI‑compatible LLM fine‑tuned on supply‑chain SOPs + RLHF (Proximal Policy Optimization) + Constraint‑Solver (OR‑Tools) |
# | **Execution Orchestrator** | Calls external APIs (ERP PO‑creation, TMS dispatch, carrier booking, finance payment‑term change) *transactionally* and records an immutable audit trail. | Kubernetes‑based micro‑agents (one per functional domain) with OpenAPI contracts; Event‑sourcing + Kafka topics for “action‑issued”, “action‑confirmed”. |
# | **Human‑in‑the‑Loop (HITL) UI** | Shows a **single‑pane dashboard** with natural‑language rationale, risk/benefit numbers, and an “Approve / Override / Defer” button. Every human decision is fed back into the learning loop. | React + Tailwind UI + Explainability layer (Chain‑of‑thought LLM output, SHAP values for feature importance). |
# | **Governance & Safety Guardrails** | Enforces *hard* business rules (e.g., no shipments to embargoed countries, carbon‑budget caps, contractual minimum volumes). Generates a signed “decision‑log” for audit. | Policy Engine (OPA – Open Policy Agent) + digital signatures; “explainability” PDFs stored on immutable storage (IPFS/S3 with WORM). |
#
# ---
#
# ## 3. Step‑by‑Step Agent Behaviour
#
# ### 3.1. Continuous Perception (Every 30 s–2 min)
#
# 1. **Data Pull** – Streams from:
#    - **IoT**: GPS, temperature, door‑open, container status.
#    - **Enterprise**: SAP ECC/4HANA (inventory, PO, DO), Oracle Transportation Management, Manhattan WMS.
#    - **External**: NOAA weather API, MarineTraffic port‑congestion API, Global‑News RSS, Twitter fire‑hose (keyword = “strike”, “port closure”), customs alerts, carrier capacity feeds.
# 2. **Normalization & Enrichment** – Each event is enriched with *entity IDs* from the KG (e.g., “Container #ABC123” → “belongs to PO 456 → supplies Plant Z”).
# 3. **Anomaly Detection** – A lightweight LLM‑based classifier + statistical outlier detector flags *potential disruptions* (e.g., “container stuck at port for > 12 h”).
#
# ### 3.2. Impact Assessment
#
# | Trigger | Simulation Flow |
# |--------|-----------------|
# | **Port closure** | 1️⃣ Pull all inbound shipments scheduled for that port in the next 72 h. <br>2️⃣ For each, compute downstream **lead‑time delta** using the KG (plant → distribution centre). <br>3️⃣ Run 1 000 Monte‑Carlo demand draws → estimate *expected stock‑out cost* per SKU. <br>4️⃣ Rank actions by **ROI = (stock‑out cost avoided – extra freight cost – penalty)**. |
# | **Supplier bankruptcy** | 1️⃣ Identify all open PO’s with the supplier. <br>2️⃣ Simulate two scenarios: (a) “continue with existing PO” (risk of non‑delivery), (b) “dual‑source from alternate supplier”. <br>3️⃣ Include *lead‑time slack* and *quality variance* in the cost model. |
# | **Severe weather** | 1️⃣ Pull forecast polygons → intersect with carrier routes. <br>2️⃣ Flag any legs with > 80 % probability of delay > 12 h. <br>3️⃣ Re‑run the routing optimiser with the affected legs removed. |
#
# The **output** is a *Risk‑Impact Card*:
#
# ```
# Event: Port of Los Angeles – Labor Strike (expected 48‑72h)
# Affected PO: #98765 (10,000 units – SKU‑A)
# Projected stock‑out cost @ 3‑day delay: $215k
# Alternative rail‑via • 3‑day: +$12k freight, –$210k stock‑out → net -$198k
# Carbon delta: +0.12 tCO2 (within budget)
# ```
#
# ### 3.3. Decision & Coordination
#
# 1. **Policy Engine** checks **hard constraints** (e.g., cannot exceed carbon budget, cannot exceed carrier’s contracted volume).
# 2. **RL‑policy** selects **which** of the feasible alternatives to execute, maximizing *expected net benefit* while respecting a *risk‑tolerance threshold* (e.g., keep MTTR ≤ 6 h).
# 3. **Multi‑Agent Negotiation** – The DMA spawns *sub‑agents* that communicate via a lightweight contract‑net protocol:
#
#    - **Procurement‑Agent** proposes a dual‑source PO to Supplier B (price $X, lead‑time 5 d).
#    - **Carrier‑Agent** proposes a rail slot at $Y with carbon‑score Z.
#    - **Finance‑Agent** checks cash‑availability & payment‑term impact.
#
#    The agents exchange *offers* and converge on a *Pareto‑optimal* bundle (price vs. carbon vs. speed).
#
# 4. **Human‑in‑the‑Loop** – If the *net benefit* exceeds a **high‑value threshold** (e.g., > $250 k), the system surfaces the *Risk‑Impact Card* plus a **natural‑language justification** generated by the LLM:
#
#    > “Because the strike will delay 30 inbound containers, we anticipate a $215k loss of sales for SKU‑A. Shipping the same volume by rail costs $12k extra freight but avoids $210k of lost sales, yielding a net gain of $198k. Carbon impact stays within the quarterly target (+0.12 tCO₂).”
#
#    The planner can **Approve**, **Override** (select a different carrier), or **Defer** (wait for more data).
#
# ### 3.4. Execution
#
# | Action | API Call | Confirmation Mechanism |
# |--------|----------|------------------------|
# | Create PO (dual‑source) | SAP PO‑Create OData | SAP returns PO‑Number → Event “po_created” emitted |
# | Book rail slot | UPS Freight API (or rail‑carrier REST) | Carrier returns booking reference → “slot_booked” event |
# | Update payment terms | Coupa / Ariba API | Finance system acknowledges → “terms_updated” |
# | Shift inventory between warehouses | WMS Transfer API | WMS confirms pick/put → “inventory_moved” |
#
# All calls are wrapped in **saga transactions**: if any step fails, a compensating transaction rolls back the preceding actions, and the DMA re‑plans.
#
# ### 3.5. Learning & Continuous Improvement
#
# - **Feedback Loop** – After the disruption resolves, the system compares *planned vs. actual* outcomes (real freight cost, actual stock‑out, carbon).
# - **Model Update** – The RL‑policy updates its Q‑values; the LLM is fine‑tuned on the new “decision‑rationale → outcome” pairs (RLHF style).
# - **Knowledge‑Graph Refresh** – New supplier‑carrier relationships discovered during negotiations are added automatically.
#
# ---
#
# ## 4. Agentic AI Architecture (Deployable Blueprint)
#
# ```
# +-----------------------------------------------------------+
# |                     DISRUPTION‑MANAGEMENT HUB            |
# |  (Kubernetes cluster – 5‑node, autoscaling)               |
# |                                                           |
# |  +-------------------+   +---------------------------+    |
# |  |   Perception Svc  |   |   KG Service (Neo4j)      |    |
# |  | (Kafka → Flink)   |   |   (temporal + geo)        |    |
# |  +-------------------+   +---------------------------+    |
# |          |                         |                     |
# |          v                         v                     |
# |  +-------------------+   +---------------------------+    |
# |  |   Impact Engine   |   |   Policy & Planning Svc   |    |
# |  | (SimPy + GPU MC)  |   | (LLM + RL + PDDL)         |    |
# |  +-------------------+   +---------------------------+    |
# |          |                         |                     |
# |          v                         v                     |
# |  +-------------------+   +---------------------------+    |
# |  |  Orchestrator API |---|  Human‑in‑the‑Loop UI      |    |
# |  |  (Saga/OPAF)      |   |  (React, Explainable AI)   |    |
# |  +-------------------+   +---------------------------+    |
# |          |                         |                     |
# |          v                         v                     |
# |  +-----------------------------------------------------+ |
# |  |  External Connectors (ERP, TMS, WMS, Carrier APIs) | |
# |  +-----------------------------------------------------+ |
# +-----------------------------------------------------------+
# ```
#
# - **Resilience** – Each micro‑service runs with side‑car health checks; Kafka topics are replicated 3‑way; Neo4j is in HA mode.
# - **Security** – Mutual TLS between services, role‑based access control (RBAC) for ERP/TMS actions, audit logs stored on immutable WORM S3 bucket.
# - **Scalability** – During peak seasons (e.g., Black Friday) the *Perception* and *Impact* services auto‑scale to handle > 10 k events/sec.
#
# ---
#
# ## 5. Concrete Action Catalog (What the DMA Can Do)
#
# | Functional Domain | Example Action | Trigger | Business Reason |
# |-------------------|----------------|--------|-----------------|
# | **Procurement** | Auto‑generate a *dual‑source* purchase order to an alternate supplier. | Supplier risk score > 80 % (e.g., bankruptcy news). | Prevents downstream stock‑out; spreads risk. |
# | **Transportation** | Re‑optimize outbound loads, switch mode (truck → rail) or carrier. | Port congestion forecast > 70 % probability of > 24 h delay. | Saves freight cost vs. expedited air; meets carbon target. |
# | **Warehouse** | Initiate *cross‑dock* or *inventory shift* between regional DCs. | Projected inventory shortfall at DC X > 3 days. | Keeps service level, reduces need for emergency air freight. |
# | **Finance** | Extend payment terms for a critical supplier in exchange for a volume discount. | Cash‑flow buffer > 10 % of working capital; high‑risk supplier. | Improves cash‑position while securing supply. |
# | **Compliance/ESG** | Enforce embargo rules: automatically block shipments to sanctioned destinations. | Customs API flags a destination on the sanctions list. | Avoids legal penalties, preserves ESG score. |
# | **Customer Service** | Send proactive “delay‑notification” messages (SMS/email) with revised ETA. | ETA shift > 12 h predicted. | Improves NPS, reduces inbound call volume. |
# | **Contract Management** | Renegotiate a freight contract clause (e.g., “force‑maje
