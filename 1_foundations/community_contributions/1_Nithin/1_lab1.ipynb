# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# This notebook uses the local Ollama-compatible OpenAI endpoint

from openai import OpenAI

OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="anything")

# %%
# All calls below use the local Ollama endpoint.
# Ensure your Ollama server is running before executing the cells.
# You can check available models with: ollama list
# !ollama list
# Out:
# NAME                       ID              SIZE      MODIFIED
# nomic-embed-text:latest    0a109f422b47    274 MB    7 weeks ago
# llama3.2:latest            a80c4f17acd5    2.0 GB    7 weeks ago
# llama3.2:3b                a80c4f17acd5    2.0 GB    5 months ago

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = ollama.chat.completions.create(model="llama3.2:3b", messages=messages)
print(response.choices[0].message.content)
# Out:
# Here's a fun fact: Did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible! Honey's unique composition, which makes it acidic and has antibacterial properties, creates a self-preserving environment that prevents the growth of bacteria and mold, allowing it to remain fresh and intact for thousands of years. Isn't that sweet?

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = ollama.chat.completions.create(model="llama3.2:3b", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# A researcher is known to spend 1/3 of their time thinking about the problem and 2/3 of their time trying to solve alternative problems. If the researcher has been working on this problem for at least 27 years, and has taken a 20% increase in output per year, how many hours per week would they be working to solve the problem, assuming 50 hours of work per week?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'A researcher is known to spend 1/3 of their time thinking about the problem and 2/3 of their time trying to solve alternative problems. If the researcher has been working on this problem for at least 27 years, and has taken a 20% increase in output per year, how many hours per week would they be working to solve the problem, assuming 50 hours of work per week?'}]

# %%
# Ask the model to answer the hard question

response = ollama.chat.completions.create(model="llama3.2:3b", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# To start, we need to break down the information provided:
#
# - The researcher's time distribution:
#     * 1/3 of the time is spent thinking about the problem,
#     * 2/3 of the time is spent trying to solve alternative problems.
# - The researcher has been working on this problem for at least 27 years.
# - The researcher has taken a 20% increase in output per year.
# - 50 hours of work per week.
#
# First, we'll find out how many hours the researcher works per year:
#
# 50 hours/week * 52 weeks/year = 2600 hours/year
#
# The 20% increase in output per year means the researcher's output is 120% of the previous year. We can write this as:
#
# Current year output = Previous year output * 1.2
#
# We can set up an equation to find the current year output.
#
# To find the current year output, we can use an example where the output is X.
#
# If we think of the output in the first year as 1, then after 1 year the output will be 1.2, then after the second year the output will be 1.2*1.2 = 1.44 and so on until now.
#
# Let's find X
#
# Since the output has been constantly increasing by 20% each year and the researcher has been working on the problem for 27 years, we will know the output in the first year to be 1. To find the output year 27, we will calculate 1.2^26.
#
# Current year output: 1.2^26 ≈ 9.9586
#
# Now we'll find how much of the current year output goes to the current problem. We know for sure that the researcher spends the same amount of time each year on this problem. We also know that 1 of every 3 years, he gets a small bonus in output due to advancements on this problem.
#
# Let x be the hours the researcher spends on the current problem. Then (1/3)x + (20% increase in bonus) is the current year's output spent on the problem. If we set (1/3)x + (15.6% of 9.9586) = the current year's output spent on this problem, we can now solve for x.
#
# The current year's output spent on the problem: 9.9586 * (1%*15.6%) (15.6%-1)%* (1-15.6%) ≈ 1.6
#
# So we get
#
# (1/3)x + (15.6% of 9.9586)
# x + 9.9586 * (0.156)
# x+ 1.566
# Equating this to 1.6, we get
# x+1.566=1.6
#
# Subtracting 1.566 from both sides of the equation, we get
#
# x= 1.6 - 1.566
# x = 0.034

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To start, we need to break down the information provided:
#
# - The researcher's time distribution:
#     * 1/3 of the time is spent thinking about the problem,
#     * 2/3 of the time is spent trying to solve alternative problems.
# - The researcher has been working on this problem for at least 27 years.
# - The researcher has taken a 20% increase in output per year.
# - 50 hours of work per week.
#
# First, we'll find out how many hours the researcher works per year:
#
# 50 hours/week * 52 weeks/year = 2600 hours/year
#
# The 20% increase in output per year means the researcher's output is 120% of the previous year. We can write this as:
#
# Current year output = Previous year output * 1.2
#
# We can set up an equation to find the current year output.
#
# To find the current year output, we can use an example where the output is X.
#
# If we think of the output in the first year as 1, then after 1 year the output will be 1.2, then after the second year the output will be 1.2*1.2 = 1.44 and so on until now.
#
# Let's find X
#
# Since the output has been constantly increasing by 20% each year and the researcher has been working on the problem for 27 years, we will know the output in the first year to be 1. To find the output year 27, we will calculate 1.2^26.
#
# Current year output: 1.2^26 ≈ 9.9586
#
# Now we'll find how much of the current year output goes to the current problem. We know for sure that the researcher spends the same amount of time each year on this problem. We also know that 1 of every 3 years, he gets a small bonus in output due to advancements on this problem.
#
# Let x be the hours the researcher spends on the current problem. Then (1/3)x + (20% increase in bonus) is the current year's output spent on the problem. If we set (1/3)x + (15.6% of 9.9586) = the current year's output spent on this problem, we can now solve for x.
#
# The current year's output spent on the problem: 9.9586 * (1%*15.6%) (15.6%-1)%* (1-15.6%) ≈ 1.6
#
# So we get
#
# (1/3)x + (15.6% of 9.9586)
# x + 9.9586 * (0.156)
# x+ 1.566
# Equating this to 1.6, we get
# x+1.566=1.6
#
# Subtracting 1.566 from both sides of the equation, we get
#
# x= 1.6 - 1.566
# x = 0.034

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# A researcher is known to spend 1/3 of their time thinking about the problem and 2/3 of their time trying to solve alternative problems. If the researcher has been working on this problem for at least 27 years, and has taken a 20% increase in output per year, how many hours per week would they be working to solve the problem, assuming 50 hours of work per week?
#
# And here is a possible answer that might be correct or incorrect:
# To start, we need to break down the information provided:
#
# - The researcher's time distribution:
#     * 1/3 of the time is spent thinking about the problem,
#     * 2/3 of the time is spent trying to solve alternative problems.
# - The researcher has been working on this problem for at least 27 years.
# - The researcher has taken a 20% increase in output per year.
# - 50 hours of work per week.
#
# First, we'll find out how many hours the researcher works per year:
#
# 50 hours/week * 52 weeks/year = 2600 hours/year
#
# The 20% increase in output per year means the researcher's output is 120% of the previous year. We can write this as:
#
# Current year output = Previous year output * 1.2
#
# We can set up an equation to find the current year output.
#
# To find the current year output, we can use an example where the output is X.
#
# If we think of the output in the first year as 1, then after 1 year the output will be 1.2, then after the second year the output will be 1.2*1.2 = 1.44 and so on until now.
#
# Let's find X
#
# Since the output has been constantly increasing by 20% each year and the researcher has been working on the problem for 27 years, we will know the output in the first year to be 1. To find the output year 27, we will calculate 1.2^26.
#
# Current year output: 1.2^26 ≈ 9.9586
#
# Now we'll find how much of the current year output goes to the current problem. We know for sure that the researcher spends the same amount of time each year on this problem. We also know that 1 of every 3 years, he gets a small bonus in output due to advancements on this problem.
#
# Let x be the hours the researcher spends on the current problem. Then (1/3)x + (20% increase in bonus) is the current year's output spent on the problem. If we set (1/3)x + (15.6% of 9.9586) = the current year's output spent on this problem, we can now solve for x.
#
# The current year's output spent on the problem: 9.9586 * (1%*15.6%) (15.6%-1)%* (1-15.6%) ≈ 1.6
#
# So we get
#
# (1/3)x + (15.6% of 9.9586)
# x + 9.9586 * (0.156)
# x+ 1.566
# Equating this to 1.6, we get
# x+1.566=1.6
#
# Subtracting 1.566 from both sides of the equation, we get
#
# x= 1.6 - 1.566
# x = 0.034
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = ollama.chat.completions.create(model="llama3.2:latest", messages=messages)
print(response.choices[0].message.content)
# Out:
# The answer you provided seems mostly correct, but there are a few issues that need to be addressed:
#
# 1. In the calculation of the current year's output spent on the problem, the 20% increase in output per year is applied to the entire output, not just the bonus. This means the researcher's output is 9.9586, and the bonus is a percentage of this output.
#
# However, you correctly calculated the 20% increase in bonus.
#
# 2. Calculating the output as a percentage of the research time spent on the problem, you get 1.6. This might be a problem, as you calculated earlier that (15.6% of 9.9586) ≈ 1.566. Since the time spent on the problem doesn't change, this should be equal to 1.6. You actually didn't use the correct formula for %.
#
# You should have just used (x+1.566)/ (x+9.9586)=1.6, because this equation is derived from 19.514 to find the % of time researcher spends on problem.
#
# So (x+1.566) = 1.6(x+9.9586)
# 1.6x+15.716 = x+15.89912
# 0.4x = 0.182432
# x = 0.182432/0.4
# x = 0.457
#
# Then 0.457 *50 ≈ 22.85
#
# Therefore, the amount of hours the researcher spends on the problem each week is not 0.034 hours, but 22.85 hours

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Suggest one industry in which worth to apply agentic ai opportunity."}]

# Then make the first call:

response = ollama.chat.completions.create(model="llama3.2", messages=messages)

# Then read the business idea:

business_area = response.choices[0].message.content

print(business_area)

# And repeat! In the next message, include the business area within the message
# Out:
# One industry where Agentic AI has tremendous potential is in **Healthcare**.
#
# Agentic AI can revolutionize the healthcare industry in several ways:
#
# 1. **Personalized Medicine**: By leveraging Agentic AI, healthcare providers can automate the process of creating personalized treatment plans for each patient. The AI can analyze vast amounts of data, such as genetic profiles, medical histories, and lifestyle information, to develop tailored treatment strategies that have a greater chance of success.
# 2. **Predictive Analytics**: Agentic AI can be applied to predict patient outcomes, identify potential health risks, and detect early warning signs of diseases. This enables healthcare providers to take proactive measures to prevent or delay complications.
# 3. **Streamlining Administrative Tasks**: Agentic AI can automate many administrative tasks, such as claim processing, scheduling, and appointment reminders, freeing up healthcare professionals to focus on more complex and high-value tasks.
# 4. **Remote Monitoring and Care**: Agentic AI-powered systems can remotely monitor patients with chronic conditions, track their progress, and adjust treatment plans accordingly.
# 5. **Imaging Analysis**: Agentic AI can be applied to image analysis, such as analyzing medical scans, allowing for faster and more accurate diagnosis of conditions.
#
# Examples of successful Agentic AI applications in healthcare include:
#
# * IBM Watson for Oncology
# * Google's DeepMind Healthcare
# * Microsoft's Health Bot
#
# By applying Agentic AI in healthcare, organizations can improve patient outcomes, reduce costs, and enhance the overall quality of care.

# %%
messages = [{"role": "user","content": f"""The industry is: {business_area}Identify one challenging pain point in this industry that might be suitable for an Agentic AI solution."""}]
response = ollama.chat.completions.create(model="llama3.2:latest",messages=messages)
pain_point = response.choices[0].message.content
print(pain_point)
# Out:
# One challenging pain point in the healthcare industry that might be suitable for an Agentic AI solution is:
#
# **Ensuring accurate and timely identification of **medical errors**,
#
# These errors can occur in various parts of the healthcare process, such as medication administration, surgical procedures, or diagnostic testing, and can result in patient harm, injury, or even fatalities.
#
# Agentic AI could potentially address this pain point in several ways:
#
# 1. **Anomaly detection**: Agentic AI-powered systems can analyze large datasets, identifying patterns and anomalies that may indicate a potential medical error.
# 2. **Predictive modeling**: By analyzing historical data and real-time patient information, Agentic AI can develop predictive models to forecast potential errors and alert healthcare providers.
# 3. **Automated review and validation**: Agentic AI can review medical records, diagnoses, and treatment plans, flagging potential errors and suggesting alternative courses of action.
# 4. **Real-time alerts and notifications**: Agentic AI-powered systems can send timely alerts and notifications to healthcare providers, flagging potential errors and empowering them to take corrective action.
#
# By addressing this pain point, Agentic AI can help improve patient safety, reduce medical errors, and enhance the overall quality of care in the healthcare industry.

# %%
messages = [{"role": "user","content": f"""The industry is: {business_area} The pain point is: {pain_point} Propose an Agentic AI solution to address this pain point. Explain how the agent would work and what actions it could take autonomously."""}]

response = ollama.chat.completions.create(model="llama3.2",messages=messages)

solution = response.choices[0].message.content

print(solution)
# Out:
# Proposed Agentic AI Solution: "MedErrorGuard"
#
# MedErrorGuard is an Agentic AI solution designed to ensure accurate and timely identification of medical errors in the healthcare industry. This agent is built to analyze vast amounts of data, identify patterns, and develop predictive models to forecast potential errors.
#
# **Architecture:**
#
# MedErrorGuard consists of the following components:
#
# 1. **Data Ingestion Module**: This module collects and aggregates data from various sources, including electronic health records, laboratory results, medical imaging, and patient feedback.
# 2. **Data Analysis Engine**: This engine processes and analyzes the collected data, identifying patterns and anomalies that may indicate a potential medical error.
# 3. **Predictive Modeling Module**: This module develops predictive models based on historical data and real-time patient information, forecasting potential errors and alerting healthcare providers.
# 4. **Automated Review and Validation Module**: This module reviews medical records, diagnoses, and treatment plans, flagging potential errors and suggesting alternative courses of action.
# 5. **Alert and Notification System**: This system sends timely alerts and notifications to healthcare providers, empowering them to take corrective action.
#
# **Agent Capabilities:**
#
# MedErrorGuard is an autonomous agent that can:
#
# 1. **Analyze medical records and diagnoses**: Identify potential errors and inconsistencies in patient records, diagnoses, and treatment plans.
# 2. **Monitor patient data in real-time**: Track patient vital signs, lab results, and medical imaging to identify potential errors during treatment.
# 3. **Develop predictive models**: Forecast potential errors and alert healthcare providers to take corrective action.
# 4. **Review literature and guidelines**: Stay up-to-date on the latest medical research, guidelines, and best practices to inform its decision-making.
# 5. **Communicate with healthcare providers**: Send alerts, notifications, and recommendations to healthcare providers, empowering them to take proactive measures to prevent or mitigate errors.
#
# **Autonomous Actions:**
#
# MedErrorGuard can take the following autonomous actions:
#
# 1. **Alerting healthcare providers**: Send timely notifications and recommendations to healthcare providers, empowering them to take corrective action.
# 2. **Flagging potential errors**: Identify and flag potential errors in patient records, diagnoses, and treatment plans, highlighting areas for review and validation.
# 3. **Suggesting alternative courses of action**: Provide healthcare providers with alternative treatment options or diagnostic approaches to mitigate potential errors.
# 4. **Collaborating with healthcare teams**: Share data and insights with healthcare teams to facilitate collaborative decision-making and improve patient care.
# 5. **Continuous learning and improvement**: Update its knowledge and expertise to reflect the latest medical research, guidelines, and best practices.
#
# By adopting MedErrorGuard, healthcare organizations can empower their staff to focus on high-value tasks while ensuring accurate and timely identification of medical errors, thereby improving patient safety, quality of care, and overall clinical outcomes.
