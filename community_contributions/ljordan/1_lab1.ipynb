# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

response = openai.chat.completions.create(
    model="gpt-5.4-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# In a sealed room, three identical boxes are labeled A, B, and C. Box A contains two black and one white ball; Box B contains two white and one black ball; Box C contains one black and two white balls. You randomly select one box (each with equal probability), then randomly draw a single ball from that box. Given that the ball drawn is white, what is the probability that the selected box was A?

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-5.4-nano",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# In a certain country, there are only three kinds of citizens: A, B, and C. Every A citizen tells the truth exactly 1 day out of 3 and lies the other 2 days; every B citizen tells the truth exactly 2 days out of 3 and lies the other 1 day; every C citizen always tells the truth. On a particular day, three citizens—one of each kind—are asked the same question: “Is it raining today?” Each answers “Yes.” Assuming all answers are consistent with the rules above and that at most one of the three citizens could be wrong on that day, determine whether it is raining today.

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'In a certain country, there are only three kinds of citizens: A, B, and C. Every A citizen tells the truth exactly 1 day out of 3 and lies the other 2 days; every B citizen tells the truth exactly 2 days out of 3 and lies the other 1 day; every C citizen always tells the truth. On a particular day, three citizens—one of each kind—are asked the same question: “Is it raining today?” Each answers “Yes.” Assuming all answers are consistent with the rules above and that at most one of the three citizens could be wrong on that day, determine whether it is raining today.'}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-5.4-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Yes — it is raining today.
#
# Reasoning:
#
# - A citizen tells the truth only \(1/3\) of the time, so saying “Yes” means they may be lying or telling the truth.
# - B citizen tells the truth \(2/3\) of the time, so they are more likely to be truthful.
# - C citizen always tells the truth, so their “Yes” is definitely correct.
#
# Since all three answered “Yes,” and at most one of them could be wrong that day, the only way this can be consistent is if the truthful answer is “Yes.” Therefore, it is raining today.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Yes — it is raining today.
#
# Reasoning:
#
# - A citizen tells the truth only \(1/3\) of the time, so saying “Yes” means they may be lying or telling the truth.
# - B citizen tells the truth \(2/3\) of the time, so they are more likely to be truthful.
# - C citizen always tells the truth, so their “Yes” is definitely correct.
#
# Since all three answered “Yes,” and at most one of them could be wrong that day, the only way this can be consistent is if the truthful answer is “Yes.” Therefore, it is raining today.

# %%
# Ask the model for a correct answer to compare against

response = openai.chat.completions.create(
    model="gpt-5.4-mini",
    messages=[{"role": "user", "content": f"Answer this question correctly and concisely:\n\n{question}"}]
)

correct_answer = response.choices[0].message.content
print(correct_answer)
# Out:
# It **is raining today**.
#
# Reason:
# - The **C** citizen always tells the truth, so if C says “Yes,” then it **is raining**.
# - Since at most one citizen could be wrong that day, the two others must be consistent with that conclusion.
# - Therefore the only possible answer is that it **is raining today**.

# %%
message = f"""
Here is a question:
{question}

Here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate the answer and provide a score between 0 and 100.

Please provide a correct answer:
{correct_answer}
"""

print(message)
# Out:
# Here is a question:
# In a certain country, there are only three kinds of citizens: A, B, and C. Every A citizen tells the truth exactly 1 day out of 3 and lies the other 2 days; every B citizen tells the truth exactly 2 days out of 3 and lies the other 1 day; every C citizen always tells the truth. On a particular day, three citizens—one of each kind—are asked the same question: “Is it raining today?” Each answers “Yes.” Assuming all answers are consistent with the rules above and that at most one of the three citizens could be wrong on that day, determine whether it is raining today.
#
# Here is a possible answer that might be correct or incorrect:
# Yes — it is raining today.
#
# Reasoning:
#
# - A citizen tells the truth only \(1/3\) of the time, so saying “Yes” means they may be lying or telling the truth.
# - B citizen tells the truth \(2/3\) of the time, so they are more likely to be truthful.
# - C citizen always tells the truth, so their “Yes” is definitely correct.
#
# Since all three answered “Yes,” and at most one of them could be wrong that day, the only way this can be consistent is if the truthful answer is “Yes.” Therefore, it is raining today.
#
# Please evaluate the answer and provide a score between 0 and 100.
#
# Please provide a correct answer:
# It **is raining today**.
#
# Reason:
# - The **C** citizen always tells the truth, so if C says “Yes,” then it **is raining**.
# - Since at most one citizen could be wrong that day, the two others must be consistent with that conclusion.
# - Therefore the only possible answer is that it **is raining today**.

# %%
messages = [{"role": "user", "content": message}]
messages

response = openai.chat.completions.create(
    model="gpt-5.4",
    messages=messages
)
print(response.choices[0].message.content)

score = response.choices[0].message.content

message = f"""
Here is the score: {score}

Here is the correct answer: {correct_answer}
"""

print(message)
# Out:
# Score: 95/100
#
# Evaluation:
# - The proposed answer reaches the correct conclusion: it is raining today.
# - The key reason is decisive: the C citizen always tells the truth, so C’s “Yes” guarantees that the correct answer to “Is it raining today?” is yes.
# - The “at most one could be wrong” condition is not actually needed to reach the conclusion, though it is compatible with it.
# - The weaker part of the reasoning is the mention of A being truthful 1/3 of the time and B 2/3 of the time as if likelihood matters here. This is not a probability question; the presence of the always-truthful C already settles it.
#
# A cleaner correct answer:
# Yes, it is raining today, because one of the three citizens is a C citizen, and C citizens always tell the truth. Since all three answered “Yes,” the C citizen’s answer must be true. Therefore, it is raining today.
#
# Here is the score: Score: 95/100
#
# Evaluation:
# - The proposed answer reaches the correct conclusion: it is raining today.
# - The key reason is decisive: the C citizen always tells the truth, so C’s “Yes” guarantees that the correct answer to “Is it raining today?” is yes.
# - The “at most one could be wrong” condition is not actually needed to reach the conclusion, though it is compatible with it.
# - The weaker part of the reasoning is the mention of A being truthful 1/3 of the time and B 2/3 of the time as if likelihood matters here. This is not a probability question; the presence of the always-truthful C already settles it.
#
# A cleaner correct answer:
# Yes, it is raining today, because one of the three citizens is a C citizen, and C citizens always tell the truth. Since all three answered “Yes,” the C citizen’s answer must be true. Therefore, it is raining today.
#
# Here is the correct answer: It **is raining today**.
#
# Reason:
# - The **C** citizen always tells the truth, so if C says “Yes,” then it **is raining**.
# - Since at most one citizen could be wrong that day, the two others must be consistent with that conclusion.
# - Therefore the only possible answer is that it **is raining today**.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be ripe for an Agentic AI solution."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-5.4-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message

messages = [{"role": "user", "content": f"Pick a pain-point in the following industry: {business_idea}"}]

response = openai.chat.completions.create(
    model="gpt-5.4-mini",
    messages=messages
)

pain_point = response.choices[0].message.content

messages = [{"role": "user", "content": f"Now propose an AI solution to the following pain-point: {pain_point}"}]

response = openai.chat.completions.create(
    model="gpt-5.4-mini",
    messages=messages
)

ai_solution = response.choices[0].message.content

message = f"""
Here is the pain-point: {pain_point}

Here is the AI solution: {ai_solution}
"""

print(message)
# Out:
# Here is the pain-point: A strong pain point to target is **e-commerce post-purchase support**, especially **“Where is my order?” (WISMO), returns/exchanges, and shipment issue handling**.
#
# ### Why this is a strong pain point
# - **High volume:** These tickets make up a large share of support contacts.
# - **Highly repetitive:** Most cases follow the same few workflows.
# - **Easy to measure ROI:** Lower ticket volume, faster resolution, fewer refunds/chargebacks.
# - **Agentic fit:** The agent can look up order status, carrier data, policy rules, and initiate actions.
#
# ### Best specific wedge
# Start with **WISMO + delivery exception handling**:
# - Order not yet shipped
# - Tracking says delayed
# - Package marked delivered but not received
# - Address change before shipment
#
# ### Why this is a good first entry point
# - Low-risk compared with refunds or complex disputes
# - Mostly reads from existing systems, so it’s easier to automate
# - Clear escalation path to humans when needed
# - Immediate customer value: fewer “just checking” contacts
#
# ### A practical agentic workflow
# 1. Intake ticket from email/chat/form
# 2. Identify intent: WISMO, return, damage, address change
# 3. Pull order data from Shopify/Magento/OMS
# 4. Pull shipment status from carrier API
# 5. Check policy/SLA rules
# 6. Auto-reply with status or next steps
# 7. Escalate if anomaly is detected
# 8. Create follow-up task if resolution is pending
#
# If you want, I can next turn this into:
# - a **startup ICP and buyer persona**
# - a **full agent workflow**
# - or a **go-to-market wedge and MVP spec**
#
# Here is the AI solution: Here’s a strong AI solution proposal for **e-commerce post-purchase support**, focused on **WISMO + delivery exceptions** as the wedge.
#
# ---
#
# ## Product concept: AI Post-Purchase Support Agent
#
# An AI agent that resolves the most common post-purchase tickets automatically by connecting to:
# - **Order systems**: Shopify, Magento, OMS
# - **Shipping/carrier APIs**: UPS, FedEx, USPS, DHL, etc.
# - **Policy engines / business rules**
# - **Support channels**: email, chat, helpdesk, contact forms
#
# It handles:
# - **“Where is my order?”**
# - **Delayed shipment / delivery exception**
# - **Marked delivered but not received**
# - **Address change before shipment**
# - later: returns, exchanges, damaged goods, refund eligibility
#
# ---
#
# ## Core value proposition
#
# Reduce support load and response time for repetitive post-purchase issues by automating:
# - order lookup
# - tracking lookup
# - policy checks
# - customer updates
# - escalation to humans only when needed
#
# ### Business outcomes
# - Fewer inbound tickets
# - Lower first response and resolution time
# - Reduced agent workload
# - Better CSAT
# - Fewer refunds / chargebacks from avoidable cases
# - Better customer trust through proactive updates
#
# ---
#
# ## Why this is a good AI wedge
#
# This is one of the best places to start because it has:
# - **High volume**: a large portion of support tickets
# - **Low complexity** for many cases
# - **Clear data sources**: order + shipment status are usually structured
# - **Repeatable workflows**
# - **Easy ROI measurement**
# - **Low risk** compared with autonomous refund decisions
#
# Unlike general customer support AI, this is not “answer anything.”
# It is a **narrow, high-value operational agent** with a bounded workflow.
#
# ---
#
# ## The AI workflow
#
# ### 1. Ticket intake
# The agent receives a message from:
# - email
# - chat
# - contact form
# - helpdesk ticket
#
# ### 2. Intent classification
# It identifies the request type:
# - WISMO
# - delayed shipment
# - delivered but not received
# - address change
# - return/exchange
# - damage/lost package
#
# ### 3. Data retrieval
# The agent queries:
# - customer identity and order history
# - order fulfillment status
# - tracking events
# - carrier exceptions
# - policy rules
# - cutoff times / SLA windows
#
# ### 4. Decisioning
# The agent determines the next best action:
# - provide shipping status
# - explain delay reason
# - confirm delivery with timestamp and carrier proof
# - advise next steps for missing package
# - block address change if already shipped
# - escalate if anomaly detected
#
# ### 5. Action execution
# The agent can:
# - reply automatically
# - draft response for human approval
# - create internal task
# - tag/escalate to exception queue
# - trigger proactive notification to the customer
#
# ### 6. Escalation logic
# Escalate when:
# - tracking is inconsistent
# - package lost in transit
# - carrier scan data is missing
# - order is high-value
# - customer disputes delivery proof
# - address change requires manual intervention
#
# ---
#
# ## MVP scope
#
# ### Start with:
# 1. **WISMO**
# 2. **Delivery delayed**
# 3. **Delivered but not received**
# 4. **Address change before shipment**
#
# ### Defer initially:
# - refunds
# - exchanges
# - fraud disputes
# - partial shipments with edge cases
# - highly customized policies
#
# This keeps the product simple, reliable, and safe.
#
# ---
#
# ## What the AI actually does
#
# ### Example: WISMO
# Customer asks: “Where is my order?”
#
# Agent:
# 1. identifies the order
# 2. checks fulfillment status
# 3. checks carrier tracking
# 4. determines whether it has shipped
# 5. responds with a personalized update:
#    - “Your order shipped on Tuesday and is expected Friday.”
#    - “It is still processing; warehouse cutoff is 6 PM.”
#    - “It’s delayed due to carrier backlog; we’re monitoring it.”
#
# ### Example: delivered but not received
# Agent:
# 1. pulls tracking proof
# 2. checks delivery timestamp and address
# 3. checks carrier notes
# 4. checks policy window
# 5. advises customer on next steps:
#    - wait 24 hours
#    - check with neighbors/mailroom
#    - open carrier investigation
#    - escalate to support
#
# ### Example: address change before shipment
# Agent:
# 1. checks if fulfillment has started
# 2. checks whether address changes are allowed
# 3. if allowed, updates OMS or creates a change request
# 4. if not allowed, explains why and offers alternatives
#
# ---
#
# ## Differentiation
#
# This solution is better than generic support AI because it is:
# - **transactional, not conversational**
# - **action-oriented**
# - **system-integrated**
# - **policy-aware**
# - **ROI-driven**
#
# The agent isn’t just answering questions. It is resolving cases.
#
# ---
#
# ## Ideal customer profile
#
# Best customers:
# - DTC brands with high order volume
# - Shopify Plus merchants
# - Mid-market e-commerce brands
# - 3PL-backed fulfillment operations
# - businesses with frequent shipping-related inquiries
#
# Best signals:
# - high WISMO ticket share
# - multiple warehouses or carriers
# - international shipping
# - seasonal spikes
# - small support team handling growing order volume
#
# ---
#
# ## Pricing model
#
# Good pricing options:
# - **per resolved ticket**
# - **per order volume tier**
# - **SaaS base fee + usage**
# - premium for human-in-the-loop workflows
#
# You can also position value based on:
# - avoided tickets
# - reduced support headcount pressure
# - fewer refunds/chargebacks
#
# ---
#
# ## MVP feature set
#
# ### Must-have
# - order lookup
# - tracking lookup
# - intent classification
# - templated + AI-generated responses
# - escalation routing
# - ticket logging
# - analytics dashboard
#
# ### Nice-to-have
# - proactive delay notifications
# - customer identity verification
# - carrier exception summaries
# - delivery anomaly detection
# - approval workflow for edge cases
#
# ---
#
# ## Key integrations
# - Shopify / Magento / BigCommerce
# - Zendesk / Gorgias / Intercom / Freshdesk
# - OMS / ERP
# - Carrier APIs
# - Slack for internal escalation
# - CRM for customer context
#
# ---
#
# ## Success metrics
# Track:
# - ticket deflection rate
# - time to first response
# - time to resolution
# - percentage resolved without human involvement
# - escalation rate
# - CSAT on post-purchase cases
# - refund/chargeback reduction
#
# ---
#
# ## Simple positioning statement
#
# **“An AI agent that resolves WISMO and delivery exception tickets by connecting your store, shipping, and support systems — cutting ticket volume and resolution time without sacrificing customer experience.”**
#
# ---
#
# If you want, I can turn this into any of these next:
# 1. a **startup one-pager**
# 2. a **full MVP spec**
# 3. a **sales pitch / homepage copy**
# 4. a **technical architecture**
# 5. a **go-to-market plan**
