# %% [markdown]
# # THIS NOTEBOOK CONTAINS INFORMATION ON HOW TO SETUP LMSTUDIO AND LOAD MODELS LOCALLY TO USING DURING THIS COURSE

# %% [markdown]
# ## First step is to install LMStudio on your local system.
# ## This is pretty straight forward and after installation it should recommend downloading an LLM model

# %%
# Run this to add lmstudio into the uv environment

# !uv add lmstudio

# %% [markdown]
# Next, import LMStudio

# %%
import lmstudio as lms
import os
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# First we need to check what LLM models we have downloaded

# %%
downloaded = lms.list_downloaded_models()
llm_only = lms.list_downloaded_models("llm")
#embedding_only = lms.list_downloaded_models("embedding")

for model in llm_only:
    print(model.model_key) #Shows the model key, which is used to load the model
# Out:
# llama-3.2-3b-instruct
# google/gemma-3-4b
# deepseek/deepseek-r1-0528-qwen3-8b
# qwen/qwen3.5-9b
# ibm/granite-4-h-tiny
# nvidia/nemotron-3-nano-4b

# %%
lms.list_loaded_models("llm")
# Out:
# [LLM(identifier='ibm/granite-4-h-tiny')]

# %% [markdown]
# Say we want to load up granite-4-h-tiny

# %%
model = lms.llm("ibm/granite-4-h-tiny")

# %%
lms.configure_default_client
# Out:
# <module 'lmstudio' from 'e:\\Coursework\\Udemy_AI_Engineer\\agents\\.venv\\Lib\\site-packages\\lmstudio\\__init__.py'>
