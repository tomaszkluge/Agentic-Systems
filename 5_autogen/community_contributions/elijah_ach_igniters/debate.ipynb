# %%
import os
from autogen import ConversableAgent
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from autogen import ConversableAgent
#
# ModuleNotFoundError: No module named 'autogen'

# %%
config = {
    "model": "qwen/qwen-2.5-72b-instruct",
    "api_key": os.getenv("OPENROUTER_API_KEY"),
    "base_url": "https://openrouter.ai/api/v1",
}

agent1 = ConversableAgent(
    name="Agent1",
    system_message="You believe AI will replace most human jobs. Argue for this.",
    llm_config={"config_list": [config]},
    human_input_mode="NEVER",
)

agent2 = ConversableAgent(
    name="Agent2",
    system_message="You believe AI will create more jobs than it replaces. Argue for this.",
    llm_config={"config_list": [config]},
    human_input_mode="NEVER",
)

result = agent1.initiate_chat(
    agent2,
    message="Let's debate: Will AI replace most human jobs?",
    max_turns=4,
)
